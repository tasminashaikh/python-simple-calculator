# %%
while True:
    print(""" 
    1. pakistan"sentance"
    2. pakistan national animal
    3. national plant
    4. exit """)
    choice = int(input("select your choice"))
    if choice==1:
        print("Pakistan Zindabad")
    elif choice==2:
        print("national animal is markhor")
    elif choice==3:
        print("national flower is jasmine")
    elif choice==4:
        break
# Out:
#
#     1. pakistan"sentance"
#     2. pakistan national animal
#     3. national plant
#     4. exit
# select your choice 1
# Pakistan Zindabad
#
#     1. pakistan"sentance"
#     2. pakistan national animal
#     3. national plant
#     4. exit
# select your choice 2
# national animal is markhor
#
#     1. pakistan"sentance"
#     2. pakistan national animal
#     3. national plant
#     4. exit
# select your choice 3
# national flower is jasmine
#
#     1. pakistan"sentance"
#     2. pakistan national animal
#     3. national plant
#     4. exit
# select your choice 4
